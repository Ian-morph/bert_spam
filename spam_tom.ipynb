# %%
import pandas as pd
df = pd.read_csv("spam.csv")

# %%
X=df['Message']
Y=df['Category']

# %%
df
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
spam_test = pd.concat([X_test, y_test], axis=1)

# %%
spam_test
# Out:
#                                                 Message Category
# 3245  Squeeeeeze!! This is christmas hug.. If u lik ...      ham
# 944   And also I've sorta blown him off a couple tim...      ham
# 1044  Mmm thats better now i got a roast down me! i...      ham
# 2484      Mm have some kanji dont eat anything heavy ok      ham
# 812   So there's a ring that comes with the guys cos...      ham
# ...                                                 ...      ...
# 4264  Den only weekdays got special price... Haiz......      ham
# 2439       I not busy juz dun wan 2 go so early.. Hee..      ham
# 5556  Yes i have. So that's why u texted. Pshew...mi...      ham
# 4205  How are you enjoying this semester? Take care ...      ham
# 4293                                              G.W.R      ham
#
# [1115 rows x 2 columns]

# %%
spam_test.to_csv('spam_test.csv', index=False)

# %%
cv = CountVectorizer()

# %%
X_train_cv = cv.fit_transform(X_train)

# %%
X_train_cv.shape
# Out:
# (4457, 7701)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
model = LogisticRegression()
model.fit(X_train_cv, y_train)
# Out:
# LogisticRegression()

# %%
# Use transform instead of fit-transform
X_test_cv = cv.transform(X_test)

# %%
pred = model.predict(X_test_cv)
cm=confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[965   1]
#  [ 15 134]]

# %%
acc = accuracy_score(y_test, pred)
print(acc)
# Out:
# 0.9856502242152466

# %%
cv
# Out:
# CountVectorizer()

# %%
import joblib

# %%
joblib.dump(cv, 'cv_encoder.pkl')
# Out:
# ['cv_encoder.pkl']

# %%
joblib.dump(model, 'lr_model.pkl')
# Out:
# ['lr_model.pkl']
